# %% [markdown]
# # Seaborn

# %% [markdown]
# ## 1: Write a Python program to create a plot to get a general Statistics of Iris data. (Using the dataset “iris.csv”).

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import preprocessing 
iris = pd.read_csv("iris.csv")
iris
# Out:
#      150    4  setosa  versicolor  virginica
# 0    5.1  3.5     1.4         0.2          0
# 1    4.9  3.0     1.4         0.2          0
# 2    4.7  3.2     1.3         0.2          0
# 3    4.6  3.1     1.5         0.2          0
# 4    5.0  3.6     1.4         0.2          0
# ..   ...  ...     ...         ...        ...
# 145  6.7  3.0     5.2         2.3          2
# 146  6.3  2.5     5.0         1.9          2
# 147  6.5  3.0     5.2         2.0          2
# 148  6.2  3.4     5.4         2.3          2
# 149  5.9  3.0     5.1         1.8          2
#
# [150 rows x 5 columns]

# %%
iris.describe().plot(kind='area')
plt.xlabel("Statistics")
plt.ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %% [markdown]
# ## 2: Write a Python program to create a graph to find relationship between the sepal length and width. (Using the dataset “iris.csv”).

# %%
sns.scatterplot(data=iris, x='sepal_length', y='petal_width', hue='species')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 sns.scatterplot(data=iris, x='sepal_length', y='petal_width', hue='species')
#
# File ~/.local/lib/python3.10/site-packages/seaborn/relational.py:603, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     594 def scatterplot(
#     595     data=None, *,
#     596     x=None, y=None, hue=None, size=None, style=None,
#    (...)
#     600     **kwargs
#     601 ):
# --> 603     p = _ScatterPlotter(
#     604         data=data,
#     605         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#     606         legend=legend
#     607     )
#     609     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     610     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# ...

# %% [markdown]
# ## 3: Write a Python program to create a join plot using "hexbin" to describe individual distributions on the same plot between Sepal length and Sepal width. (Using the dataset “iris.csv”).

# %%
sns.jointplot(x="sepal.length",y="sepal.width",data=iris,kind='hex',color='orange')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 sns.jointplot(x="sepal.length",y="sepal.width",data=iris,kind='hex',color='orange')
#
# File ~/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:2243, in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2240     dropna = True
#    2242 # Initialize the JointGrid object
# -> 2243 grid = JointGrid(
#    2244     data=data, x=x, y=y, hue=hue,
#    2245     palette=palette, hue_order=hue_order, hue_norm=hue_norm,
#    2246     dropna=dropna, height=height, ratio=ratio, space=space,
#    2247     xlim=xlim, ylim=ylim, marginal_ticks=marginal_ticks,
#    2248 )
#    2250 if grid.hue is not None:
#    2251     marginal_kws.setdefault("legend", False)
#
# ...

# %% [markdown]
# ## 4: Write a Python program to create a join plot and add regression and kernel density fits using "reg" to describe individual distributions on the same plot between Sepal length and Sepal width. (Using the dataset “iris.csv”).

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
iris1=pd.read_csv("iris.csv")
X_train, X_test, y_train, y_test = train_test_split(iris1[['SepalLengthCm', 'SepalWidthCm']], iris1['Species'], test_size=0.25)
reg = LinearRegression()
sns.jointplot(x='SepalLengthCm', y='SepalWidthCm', data=iris1, kind='reg',color="red")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 4
#       2 from sklearn.model_selection import train_test_split
#       3 iris1=pd.read_csv("iris.csv")
# ----> 4 X_train, X_test, y_train, y_test = train_test_split(iris1[['SepalLengthCm', 'SepalWidthCm']], iris1['Species'], test_size=0.25)
#       5 reg = LinearRegression()
#       6 sns.jointplot(x='SepalLengthCm', y='SepalWidthCm', data=iris1, kind='reg',color="red")
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# ...

# %% [markdown]
# ## 5: Write a Python program to find the correlation between variables of iris data. Also create a heat map using Seaborn to present their relations (Using the dataset “iris.csv”).

# %%
X = iris1.iloc[:, 1:5]
corr = X.corr()
corr
# Out:
#                    4    setosa  versicolor  virginica
# 4           1.000000 -0.428440   -0.366126  -0.426658
# setosa     -0.428440  1.000000    0.962865   0.949035
# versicolor -0.366126  0.962865    1.000000   0.956547
# virginica  -0.426658  0.949035    0.956547   1.000000

# %%
sns.heatmap(corr, cmap=sns.diverging_palette(220, 10, as_cmap=True),square=True, linewidths=.5)
# Out:
# <Axes: >
